# %% [markdown]
# # Fabfed Credential Helper
#
# The Fabfed credential file is a YAML file that contains account information and keying material for each provider using sections aka profiles.
# See [fabfed credential template](../fabfed_config/fabfed_credentials_template.yml) and link it to the standard location.

# %%
## Fabric

'''
Use the code below to dump the fabfed credentials. Use Copy and paste
to replace the fabric section in the credential file. 

Note: Be sure to manually handle entries with 'REPLACE_ME'
'''

import demo_helper as dh

fabric_rc_path = '~/work/fabric_config/fabric_rc'

dh.parse_and_dump_fabric_credentials(fabric_rc_path)

# %%
##  Chameleon

'''
Use the code below to dump the fabfed credentials. Use Copy and paste
to modify the chi section in the credential file. 

ProjectName can be found here.
See https://chi.tacc.chameleoncloud.org/identity/
See https://chi.uc.chameleoncloud.org/project/

Chameleon has different project ids for CHI@TACC and CHI@UC. These can be found in uc and tacc
opendstack rc files.  
See https://chi.tacc.chameleoncloud.org/project/api_access/openrc/
See https://chi.uc.chameleoncloud.org/project/api_access/openrc/

ProjectName can be found here. It usually starts with CH.
See https://chi.tacc.chameleoncloud.org/identity/
See https://chi.uc.chameleoncloud.org/project/

It is best to have same keypair for CHI@TACC and CHI@UC
See https://chi.tacc.chameleoncloud.org/project/key_pairs/
See https://chi.uc.chameleoncloud.org/project/key_pairs/

Note: Be sure to manually handle entries with 'REPLACE_ME'
'''

import demo_helper as dh

chi_rc_path =

dh.parse_and_dump_chameleon_credentials(chi_rc_path)
